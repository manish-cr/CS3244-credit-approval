# %%
import numpy as np
import pandas as pd
import pickle

# %%
# Opening up the files
with open("../data/my_pickled_data.pkl","rb") as file:
    data_list=pickle.load(file)

# %%
X_train_2label=data_list[0]
y_train_2label=data_list[1]
X_test_2label=data_list[2]
y_test_2label=data_list[3]

X_train_oversampled = pd.read_csv("../data/X_train_oversampling.csv")
X_train_oversampled = X_train_oversampled.iloc[:, 1:]
y_train_oversampled = pd.read_csv("../data/y_train_oversampling.csv")['Credit_Status']

# %% [markdown]
# ## RFC without feat. selection

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Create an instance of the RFC.
rfc = RandomForestClassifier(n_estimators=100, random_state=42)  # You can adjust hyperparameters as needed.

# Fit the RFC to training data.
rfc.fit(X_train_oversampled, y_train_oversampled)

# Make predictions on test data.
y_pred_2label = rfc.predict(X_test_2label)

# Generate a classification report.
report = classification_report(y_test_2label, y_pred_2label)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.16      0.36      0.22       178
#         Good       0.98      0.95      0.97      7034
#
#     accuracy                           0.94      7212
#    macro avg       0.57      0.66      0.60      7212
# weighted avg       0.96      0.94      0.95      7212

# %%
rfc_plot = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=42)  # You can adjust other hyperparameters as needed.

# Fit the RFC to training data.
rfc_plot.fit(X_train_2label, y_train_2label)
# Out:
# RandomForestClassifier(max_depth=3, random_state=42)

# %% [markdown]
# Tree plotting and important features

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn import tree
import os

# Access one of the decision trees from the Random Forest (e.g., the first one)
tree_to_visualize = rfc_plot.estimators_[0] 

plt.figure(figsize=(18, 10))

# Plot the decision tree
tree.plot_tree(tree_to_visualize, filled=True, feature_names=X_test_2label.columns.tolist())

# Create the 'plots' directory if it doesn't exist
output_folder = '../plots/'
os.makedirs(output_folder, exist_ok=True)

# Save the plot in the 'plots' directory as 'decision_tree.png'
output_path = os.path.join(output_folder, 'decision_tree.png')
plt.savefig(output_path)

# Show the plot
plt.show()

# %% [markdown]
# Text version

# %%
from sklearn.tree import export_text

# Access one of the decision trees from the Random Forest (e.g., the first one)
tree_to_visualize = rfc.estimators_[0]  # Replace 0 with the index of the tree you want to visualize

# Extract the decision tree as text
tree_text = export_text(tree_to_visualize, feature_names=X_test_2label.columns.tolist())

# Print or use the tree text
print(tree_text)
# Out:
# |--- NAME_EDUCATION_TYPE_Higher education <= 1.00
# |   |--- FLAG_EMAIL_1 <= 1.00
# |   |   |--- CNT_FAM_MEMBERS <= -1.31
# |   |   |   |--- NAME_EDUCATION_TYPE_Higher education <= 0.00
# |   |   |   |   |--- OCCUPATION_TYPE_Security staff <= 0.01
# |   |   |   |   |   |--- NAME_FAMILY_STATUS_Widow <= 1.00
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.01
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant <= 0.01
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff <= 0.04
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Widow <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Widow >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff >  0.04
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant >  0.01
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.50
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Medicine staff <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Medicine staff >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_M >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.01
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.07
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.31
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.20
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.31
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married <= 0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married >  0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.07
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special <= 0.12
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special >  0.12
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.96
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |--- NAME_FAMILY_STATUS_Widow >  1.00
# |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.01
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 0.01
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher <= 0.03
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Cleaning staff <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Cleaning staff >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher >  0.03
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -1.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -1.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  0.01
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.01
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.31
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_M >  0.01
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.01
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown <= 0.50
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.04
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.66
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.66
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.04
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.69
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.69
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- OCCUPATION_TYPE_Security staff >  0.01
# |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.99
# |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.99
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.99
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant <= 0.94
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 0.00
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Cooking staff <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Cooking staff >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant >  0.94
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 0.26
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  0.26
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.99
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- NAME_EDUCATION_TYPE_Higher education >  0.00
# |   |   |   |   |--- class: 0.0
# |   |   |--- CNT_FAM_MEMBERS >  -1.31
# |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special <= 1.00
# |   |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special <= 0.00
# |   |   |   |   |   |--- CODE_GENDER_F <= 0.01
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.91
# |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_1 <= 0.02
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education <= 0.02
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education >  0.02
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_1 >  0.02
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Drivers <= 0.02
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Drivers >  0.02
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.91
# |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary <= 0.12
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education <= 0.02
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education >  0.02
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary >  0.12
# |   |   |   |   |   |   |   |   |--- CNT_CHILDREN <= 0.09
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- CNT_CHILDREN >  0.09
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary <= 0.94
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary >  0.94
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Pensioners <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Pensioners >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- CODE_GENDER_F >  0.01
# |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff <= 0.02
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.73
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.83
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.89
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.89
# |   |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary <= 0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Lower secondary >  0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.83
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_M >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.73
# |   |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_1 <= 0.99
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_1 >  0.99
# |   |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 <= 0.95
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 >  0.95
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff >  0.02
# |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 0.62
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- DAYS_BIRTH >  0.62
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special >  0.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special >  1.00
# |   |   |   |   |--- OCCUPATION_TYPE_Sales staff <= 1.00
# |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown <= 1.00
# |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= -0.22
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  -0.22
# |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 <= 1.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 >  1.00
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 1.00
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Sales staff <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 41
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Sales staff >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  1.00
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- CNT_CHILDREN <= 0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- CNT_CHILDREN >  0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown >  1.00
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.99
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 1.00
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.00
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  1.00
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.50
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -1.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -1.04
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.50
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_Municipal apartment <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_Municipal apartment >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.99
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.05
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 1.45
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.47
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_0 <= 0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_WORK_PHONE_0 >  0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.47
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  1.45
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 1.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  1.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.05
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- OCCUPATION_TYPE_Sales staff >  1.00
# |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.00
# |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.14
# |   |   |   |   |   |   |   |--- CNT_CHILDREN <= 1.43
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- CNT_CHILDREN >  1.43
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.50
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.14
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.55
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.55
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_F <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_F >  0.50
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.97
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage <= 0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage >  0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.97
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.00
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.00
# |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_With parents <= 0.01
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage <= 0.50
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage >  0.50
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_With parents >  0.01
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.50
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.58
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.00
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 1.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  1.00
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married <= 0.01
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married >  0.01
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |--- FLAG_EMAIL_1 >  1.00
# |   |   |--- CNT_FAM_MEMBERS <= 0.77
# |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.01
# |   |   |   |   |--- DAYS_EMPLOYED <= 0.05
# |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married >  0.50
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant <= 0.50
# |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Secondary / secondary special >  0.50
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.02
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.02
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant >  0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- DAYS_EMPLOYED >  0.05
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.01
# |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education <= 0.00
# |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.00
# |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.58
# |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married >  0.50
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  0.59
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 2.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  2.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.58
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 1.71
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.50
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -1.26
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -1.26
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_M >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.50
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Incomplete higher >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  1.71
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.46
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Single / not married >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.46
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.00
# |   |   |   |   |   |   |--- OCCUPATION_TYPE_IT staff <= 0.01
# |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= -0.76
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.50
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.50
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  -0.76
# |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.97
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.97
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- OCCUPATION_TYPE_IT staff >  0.01
# |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.02
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated <= 0.01
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated >  0.01
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.02
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education >  0.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |--- CNT_FAM_MEMBERS >  0.77
# |   |   |   |--- CODE_GENDER_F <= 0.87
# |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.50
# |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education <= 0.01
# |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.06
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.06
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.50
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.13
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.13
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.50
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.50
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- NAME_EDUCATION_TYPE_Higher education >  0.01
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- CODE_GENDER_F >  0.87
# |   |   |   |   |--- DAYS_BIRTH <= 0.72
# |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.50
# |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.50
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.50
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 0.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  0.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- DAYS_BIRTH >  0.72
# |   |   |   |   |   |--- class: 1.0
# |--- NAME_EDUCATION_TYPE_Higher education >  1.00
# |   |--- FLAG_WORK_PHONE_0 <= 0.00
# |   |   |--- FLAG_OWN_REALTY_Y <= 0.01
# |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |--- OCCUPATION_TYPE_Sales staff <= 0.50
# |   |   |   |   |   |--- CNT_CHILDREN <= 0.09
# |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage <= 0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage >  0.50
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_State servant >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- CNT_CHILDREN >  0.09
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- OCCUPATION_TYPE_Sales staff >  0.50
# |   |   |   |   |   |--- CODE_GENDER_F <= 0.50
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- CODE_GENDER_F >  0.50
# |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.50
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.50
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |--- OCCUPATION_TYPE_Sales staff <= 0.50
# |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 0.03
# |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff <= 0.50
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.50
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.50
# |   |   |   |   |   |   |   |   |   |--- CNT_CHILDREN <= 1.43
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- CNT_CHILDREN >  1.43
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Accountants <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Accountants >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.50
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 1.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  1.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- OCCUPATION_TYPE_Core staff >  0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  0.03
# |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.50
# |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= -0.76
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  -0.76
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers <= 0.98
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Laborers >  0.98
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_M >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- OCCUPATION_TYPE_Sales staff >  0.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- FLAG_OWN_REALTY_Y >  0.01
# |   |   |   |--- CNT_FAM_MEMBERS <= -0.22
# |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff <= 0.50
# |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.50
# |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 3.91
# |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 1.07
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.16
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.16
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- DAYS_BIRTH >  1.07
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  3.91
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff >  0.50
# |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- CNT_FAM_MEMBERS >  -0.22
# |   |   |   |   |--- DAYS_BIRTH <= 0.55
# |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.38
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.16
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 0.43
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.43
# |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= 0.33
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  0.33
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.16
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.93
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.93
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.38
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- DAYS_BIRTH >  0.55
# |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage <= 0.00
# |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff <= 0.01
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown <= 0.00
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_M >  0.50
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.49
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Unknown >  0.00
# |   |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.50
# ...
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Medicine staff <= 0.47
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N <= 0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_N >  0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Medicine staff >  0.47
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.30
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- DAYS_EMPLOYED >  1.72
# |   |   |   |   |   |--- DAYS_BIRTH <= -2.01
# |   |   |   |   |   |   |--- DAYS_BIRTH <= -2.11
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- DAYS_BIRTH >  -2.11
# |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Married >  0.50
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 1.85
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  1.85
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- DAYS_BIRTH >  -2.01
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- NAME_FAMILY_STATUS_Separated >  0.50
# |   |   |   |   |--- AMT_INCOME_TOTAL <= -0.08
# |   |   |   |   |   |--- CODE_GENDER_F <= 0.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- CODE_GENDER_F >  0.50
# |   |   |   |   |   |   |--- DAYS_BIRTH <= -1.74
# |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -2.05
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -2.05
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- DAYS_BIRTH >  -1.74
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- AMT_INCOME_TOTAL >  -0.08
# |   |   |   |   |   |--- DAYS_EMPLOYED <= 1.48
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.50
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y <= 0.50
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 0.55
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 1.37
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  1.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.55
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- FLAG_OWN_CAR_Y >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- DAYS_EMPLOYED >  1.48
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- DAYS_BIRTH >  -1.42
# |   |   |   |--- OCCUPATION_TYPE_Core staff <= 0.00
# |   |   |   |   |--- FLAG_WORK_PHONE_0 <= 1.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- FLAG_WORK_PHONE_0 >  1.00
# |   |   |   |   |   |--- CNT_FAM_MEMBERS <= 1.97
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 1.00
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 0.37
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff <= 0.00
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- CNT_CHILDREN <= 0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- CNT_CHILDREN >  0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_0 >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff >  0.00
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.37
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers <= 0.03
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers >  0.03
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Secretaries <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Secretaries >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  1.00
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Accountants <= 0.96
# |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= 0.92
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 0.34
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 <= 0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 >  0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  0.34
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_HR staff <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_HR staff >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  0.92
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Accountants >  0.96
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.50
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- CNT_FAM_MEMBERS >  1.97
# |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_Office apartment <= 0.04
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.99
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.10
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Secretaries <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Secretaries >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_High skill tech staff >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.10
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.99
# |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.93
# |   |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 <= 0.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 >  0.75
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.93
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- OCCUPATION_TYPE_Managers >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_Office apartment >  0.04
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.96
# |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment <= 0.13
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- NAME_HOUSING_TYPE_House / apartment >  0.13
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.96
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- OCCUPATION_TYPE_Core staff >  0.00
# |   |   |   |   |--- OCCUPATION_TYPE_Core staff <= 1.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- OCCUPATION_TYPE_Core staff >  1.00
# |   |   |   |   |   |--- FLAG_EMAIL_1 <= 1.00
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N <= 0.02
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working <= 0.91
# |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 <= 0.91
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- FLAG_EMAIL_0 >  0.91
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -2.92
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= -3.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -3.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  -2.92
# |   |   |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= -0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  -0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Working >  0.91
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH <= -0.33
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= 0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Separated >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- DAYS_BIRTH >  -0.33
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED <= 0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- DAYS_EMPLOYED >  0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- NAME_FAMILY_STATUS_Civil marriage >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- FLAG_OWN_REALTY_N >  0.02
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 2.54
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= -1.15
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  -1.15
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F <= 0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- CODE_GENDER_F >  0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  2.54
# |   |   |   |   |   |   |   |   |--- CNT_CHILDREN <= 0.10
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- FLAG_PHONE_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- CNT_CHILDREN >  0.10
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- FLAG_EMAIL_1 >  1.00
# |   |   |   |   |   |   |--- CNT_FAM_MEMBERS <= -0.76
# |   |   |   |   |   |   |   |--- CODE_GENDER_M <= 0.50
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- NAME_INCOME_TYPE_Commercial associate >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- CODE_GENDER_M >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- CNT_FAM_MEMBERS >  -0.76
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y <= 0.50
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL <= 1.92
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- AMT_INCOME_TOTAL >  1.92
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- FLAG_OWN_REALTY_Y >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1.0

# %%
import matplotlib.pyplot as plt
from yellowbrick.model_selection import FeatureImportances

# Create a larger figure size
plt.figure(figsize=(5, 6))

# Create and fit the visualizer
visualizer = FeatureImportances(rfc, topn=10)  # Specify topn=10 for the top 10 features
visualizer.fit(X_train_2label, y_train_2label)

# Finalize the plot
visualizer.show()
# Out:
# c:\Users\lisal\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'Feature Importances of Top 10 Features using RandomForestClassifier'}, xlabel='relative importance'>

# %% [markdown]
# ### Model Evaluation wo feat selection

# %%
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, precision_recall_curve, f1_score, auc, ConfusionMatrixDisplay

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(y_test_2label, y_pred_2label)
cm_display_rfc = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['Bad', 'Good'])
cm_display_rfc.plot()
plt.show()

# %% [markdown]
# #### AUC-ROC

# %%
# Score

rfc_probs = rfc.predict_proba(X_test_2label)
rfc_probs = rfc_probs[:,1] # keeping probabilities for the positive outcome ?? probabilities that the model assigned to the examples being positive
rfc_auc = roc_auc_score(y_test_2label, rfc_probs)
print(f"ROC-AUC score: {round(rfc_auc, 3)}")
# Out:
# ROC-AUC score: 0.719

# %%
# AUC-ROC Plot 

y_test_2label_binary = y_test_2label.replace(['Bad', 'Good'], [0, 1]) # label 0 for bad, label 1 for good

rfc_fpr, rfc_tpr, _ = roc_curve(y_test_2label_binary, rfc_probs)

# to get the no skill line
ns_probs = [0 for _ in range(len(y_test_2label))]
ns_fpr, ns_tpr, _ = roc_curve(y_test_2label_binary, ns_probs)

#plotting
plt.plot(ns_fpr, ns_tpr, linestyle = '--', label = "No Skill")
plt.plot(rfc_fpr, rfc_tpr, marker = '.', label = "Random Forest Classifier")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# #### Precision-Recall Curve

# %%
# Precision recall score 

y_pred_2label_binary = [0 if p == 'Bad' else 1 for p in y_pred_2label] # label 0 for bad, label 1 for good

rfc_precision, rfc_recall, _ = precision_recall_curve(y_test_2label_binary, rfc_probs)
rfc_f1, rfc_auc = f1_score(y_test_2label_binary, y_pred_2label_binary), auc(rfc_recall, rfc_precision)
print(f"f1-score: {round(rfc_f1, 3)}\nauc={round(rfc_auc, 3)}")
# Out:
# f1-score: 0.968
# auc=0.989

# %%
# Precision- Recall curve 
no_skill = len(y_test_2label_binary[y_test_2label_binary==1])/len(y_test_2label_binary)
plt.plot([0,1], [no_skill, no_skill], linestyle = '--', label = 'No Skill')
plt.plot(rfc_recall, rfc_precision, marker = '.', label = "Random Forest Classifier")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %%
from yellowbrick.classifier import precision_recall_curve # this gives a clearer PR-curve but has the same function name as sklearn.metrics.precision_recall_curve
y_train_2label_binary = y_train_2label.replace(['Bad', 'Good'], [0, 1])
viz_rfc = precision_recall_curve(RandomForestClassifier(n_estimators=100, random_state=42), X_train_2label, y_train_2label_binary, X_test_2label, y_test_2label_binary)

# This PR curve and the one above should be showing the same thing except that the one on top is 'zoomed in'.
